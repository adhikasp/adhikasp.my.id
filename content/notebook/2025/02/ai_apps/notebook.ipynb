# %%
from google_play_scraper import search
import pandas as pd

result = search(
    "AI chat",
    lang="en",
    country="id",
)
df = pd.DataFrame(result)
df
# Out:
#                                                 appId  \
# 0                           ai.socialapps.speakmaster
# 1                                    ai.character.app
# 2                                  com.openai.chatgpt
# 3                                 com.weaver.app.prod
# 4                                   com.bagel.anydoor
# 5                                     com.poe.android
# 6                        com.google.android.apps.bard
# 7                                    mobile.dopple.ai
# 8                           ai.perplexity.app.android
# 9                                     com.flow.mobile
# 10                                     com.larus.wolf
# 11                                 com.scaleup.chatai
# 12                              com.microsoft.copilot
# 13                   com.Beauchamp.Messenger.external
# 14                        com.smartwidgetlabs.chatgpt
# 15                             com.qianfan.aihomework
# ...
